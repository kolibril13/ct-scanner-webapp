# %%
#from ..emoji_playground import *
from PIL import Image
import matplotlib.pyplot as plt
import requests

import io
import numpy as np
from numpy import asarray

from skimage.transform import swirl, PiecewiseAffineTransform, warp
from skimage.filters import butterworth
import pathlib
from skimage.transform import radon, rescale
from skimage.color import rgba2rgb,rgb2gray
from skimage.transform import iradon
import jupyter_capture_output


def tomo_missing_angle_clip(emoji_data,fromangle,toangle):
    total_angle = 180
    image = rgb2gray(rgba2rgb(emoji_data)) # remove alpha channel and convert to gray
    image = rescale(image, scale=0.5, mode='reflect', channel_axis=None)
    fromangle = int(fromangle* max(image.shape)/total_angle)  # TODO radon images = max(image.shape) and angle = 180
    toangle = int(toangle* max(image.shape)/total_angle )
    theta = np.linspace(0., total_angle, max(image.shape), endpoint=False)
    sinogram = radon(image, theta=theta)

    theta = theta[fromangle:toangle]
    sinogram=sinogram[:,fromangle:toangle]

    reconstruction_fbp = iradon(sinogram, theta=theta, filter_name='shepp-logan')
    reconstruction_fbp = np.clip((reconstruction_fbp)/0.9, 0,1)
    return reconstruction_fbp

# plt.rcParams['figure.dpi'] = 150  

import matplotlib.pyplot as plt  # NOT

# %config InlineBackend.print_figure_kwargs = {'pad_inches':0} # NOT


def show(img , cmap = "gray"):
    plt.imshow(img , cmap)
    plt.axis("off")
# Out:
# Jupyter Capture Output v0.0.5

# %%
current_emoji = "🦴"
current_filter_name = "without_fbp" 

emoji_code = "-".join(f"{ord(c):x}" for c in current_emoji).upper()
url = f"https://raw.githubusercontent.com/hfg-gmuend/openmoji/master/color/618x618/{emoji_code}.png"
emoji_data = Image.open(requests.get(url, stream=True).raw)
emoji_data = np.array(emoji_data.convert("RGBA"))

# %%
filtered_image1 = (tomo_missing_angle_clip(emoji_data, fromangle= 0,toangle = 1))
show(filtered_image1)
# Out:
# /Users/jan-hendrik/projects/ct-scanner-webapp/emoji_ct_env/lib/python3.10/site-packages/skimage/transform/radon_transform.py:75: UserWarning: Radon transform: image must be zero outside the reconstruction circle
#   warn('Radon transform: image must be zero outside the '

# %%
filtered_image2 = (tomo_missing_angle_clip(emoji_data, fromangle= 44,toangle = 45)) 
show(filtered_image2)

# %%
filtered_image3 = (tomo_missing_angle_clip(emoji_data, fromangle= 89,toangle = 90)) #+ tomo_missing_angle_clip(emoji_data, fromangle= 90,toangle = 91))/2
show(filtered_image3)

# %%
imgs = []
for i in range(0,180):
    filtered_im = tomo_missing_angle_clip(emoji_data, fromangle= i,toangle = i+1)
    imgs.append(filtered_im)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/jan-hendrik/projects/ct-scanner-webapp/minimal_example/Generate_Clipped_Images.ipynb Cell 6 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/Users/jan-hendrik/projects/ct-scanner-webapp/minimal_example/Generate_Clipped_Images.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> imgs = []
#       <a href='vscode-notebook-cell:/Users/jan-hendrik/projects/ct-scanner-webapp/minimal_example/Generate_Clipped_Images.ipynb#W5sZmlsZQ%3D%3D?line=1'>2</a> for i in range(0,180):
# ----> <a href='vscode-notebook-cell:/Users/jan-hendrik/projects/ct-scanner-webapp/minimal_example/Generate_Clipped_Images.ipynb#W5sZmlsZQ%3D%3D?line=2'>3</a>     filtered_im = tomo_missing_angle_clip(emoji_data, fromangle= i,toangle = i+1)
#       <a href='vscode-notebook-cell:/Users/jan-hendrik/projects/ct-scanner-webapp/minimal_example/Generate_Clipped_Images.ipynb#W5sZmlsZQ%3D%3D?line=3'>4</a>     imgs.append(filtered_im)
#
# /Users/jan-hendrik/projects/ct-scanner-webapp/minimal_example/Generate_Clipped_Images.ipynb Cell 6 in tomo_missing_angle_clip(emoji_data, fromangle, toangle)
#      <a href='vscode-notebook-cell:/Users/jan-hendrik/projects/ct-scanner-webapp/minimal_example/Generate_Clipped_Images.ipynb#W5sZmlsZQ%3D%3D?line=23'>24</a> toangle = int(toangle* max(image.shape)/total_angle )
#      <a href='vscode-notebook-cell:/Users/jan-hendrik/projects/ct-scanner-webapp/minimal_example/Generate_Clipped_Images.ipynb#W5sZmlsZQ%3D%3D?line=24'>25</a> theta = np.linspace(0., total_angle, max(image.shape), endpoint=False)
# ---> <a href='vscode-notebook-cell:/Users/jan-hendrik/projects/ct-scanner-webapp/minimal_example/Generate_Clipped_Images.ipynb#W5sZmlsZQ%3D%3D?line=25'>26</a> sinogram = radon(image, theta=theta)
#      <a href='vscode-notebook-cell:/Users/jan-hendrik/projects/ct-scanner-webapp/minimal_example/Generate_Clipped_Images.ipynb#W5sZmlsZQ%3D%3D?line=27'>28</a> theta = theta[fromangle:toangle]
#      <a href='vscode-notebook-cell:/Users/jan-hendrik/projects/ct-scanner-webapp/minimal_example/Generate_Clipped_Images.ipynb#W5sZmlsZQ%3D%3D?line=28'>29</a> sinogram=sinogram[:,fromangle:toangle]
#
# File ~/projects/ct-scanner-webapp/emoji_ct_env/lib/python3.10/site-packages/skimage/transform/radon_transform.py:105, in radon(image, theta, circle, preserve_range)
#     101     cos_a, sin_a = np.cos(angle), np.sin(angle)
#     102     R = np.array([[cos_a, sin_a, -center * (cos_a + sin_a - 1)],
#     103                   [-sin_a, cos_a, -center * (cos_a - sin_a - 1)],
#     104                   [0, 0, 1]])
# --> 105     rotated = warp(padded_image, R, clip=False)
#     106     radon_image[:, i] = rotated.sum(0)
#     107 return radon_image
#
# File ~/projects/ct-scanner-webapp/emoji_ct_env/lib/python3.10/site-packages/skimage/transform/_warps.py:944, in warp(image, inverse_map, map_args, output_shape, order, mode, cval, clip, preserve_range)
#     942 ctype = 'float32_t' if image.dtype == np.float32 else 'float64_t'
#     943 if image.ndim == 2:
# --> 944     warped = _warp_fast[ctype](image, matrix,
#     945                                output_shape=output_shape,
#     946                                order=order, mode=mode, cval=cval)
#     947 elif image.ndim == 3:
#     948     dims = []
#
# KeyboardInterrupt:

# %%
imgs20 = imgs[::9]

# %%
mode = "discrete"
path = pathlib.Path.cwd() / f"imgs_{mode}_clipped"
path.mkdir(exist_ok=True)
for i, im in enumerate(imgs20):
    plt.imshow(im, cmap="gray")
    plt.axis("off")
    plt.savefig(f"imgs_{mode}_clipped/img_{mode}_{i+1:0>3}.png", bbox_inches="tight", pad_inches=0)

# %%
img_final = imgs20[0]*0

for im in imgs20:
    img_final += im

plt.imshow(img_final,cmap="gray")
#plt.imshow(np.clip((img_final)/20, 0,1), cmap="gray")

# %%
from pathlib import Path

path = Path.cwd() / "imgs_discrete_clipped"


imgs = []

for p in path.iterdir():
    imgs.append(plt.imread(p))


img_final = np.zeros(imgs[0].shape)


# imgs = imgs[5:]
# imgs = imgs[:-5]

for im in imgs:
    img_final += im / len(imgs)

plt.imshow(img_final)
plt.axis("off")
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (-0.5, 451.5, 452.5, -0.5)

# %% [markdown]
# # Continous

# %%
imgs = []
for i in range(0,20):
    filtered_im = tomo_missing_angle_clip(emoji_data, fromangle= (i)*9,toangle = (i+1)*9)
    imgs.append(filtered_im)

# %%
mode = "continous"
path = pathlib.Path.cwd() / f"imgs_{mode}_clipped"
path.mkdir(exist_ok=True)
for i, im in enumerate(imgs):
    plt.imshow(im, cmap="gray")
    plt.axis("off")
    plt.savefig(f"imgs_{mode}_clipped/img_{mode}_{i+1:0>3}.png", bbox_inches="tight", pad_inches=0)

# %%
img_final = imgs[0]*0

for im in imgs:
    img_final += im/20


plt.imshow(np.clip((img_final)/0.9, 0,1), cmap="gray")
plt.axis("off")
# Out:
# (-0.5, 308.5, 308.5, -0.5)
